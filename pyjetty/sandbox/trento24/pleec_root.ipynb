# %%
import pleec_root
# Out:
# Welcome to JupyROOT 6.28/06

# %%
def eec_lund_plot(sconfig):

	args, args_default = pleec_root.args_from_sconfig(sconfig)

	eec_plot = pleec_root.EECplot(args)

# %%
#eec_lund_plot('-i test.yaml')
#eec_lund_plot('-i test_root.yaml --output UE')
eec_lund_plot('-i various.yaml --output various')
eec_lund_plot('-i glue_splittings.yaml --output gluon_splits')
eec_lund_plot('-i flavor.yaml --output flavor')
eec_lund_plot('-i kt_cut.yaml --output kt_cut')
eec_lund_plot('-i max_kt.yaml --output max_kt')
eec_lund_plot('-i flavor.yaml --output flavor')
eec_lund_plot('-i quench.yaml --output quench --palette flare')
eec_lund_plot('-i scaling.yaml --output scaling')
eec_lund_plot('-i UE.yaml --output UE')
# Out:
# [i] settings summary:
# PLOT: glue_no_sel SPECS: {'title': 'gluon_no_selection', 'args': '--logx', 'lg': '-i eec_lund_gluons_100GeV_50000_noUE.parquet --title "gluons"', 'lg0': '-i eec_lund_gluons_100GeV_50000_noUE.parquet --title "split 0" --nsplit 0 --lund-eec --line-color w', 'lg0AA': '-i eec_lund_gluons_100GeV_50000_noUE.parquet --title "AA" --nsplit 0 --lund-eec --eec-types 0', 'lg0AB': '-i eec_lund_gluons_100GeV_50000_noUE.parquet --title "AB" --nsplit 0 --lund-eec --eec-types 1', 'lg0BB': '-i eec_lund_gluons_100GeV_50000_noUE.parquet --title "BB" --nsplit 0 --lund-eec --eec-types 2'}
# - sub item title : gluon_no_selection
# - sub item args : --logx
# [i] settings summary:
# - sub item lg : -i eec_lund_gluons_100GeV_50000_noUE.parquet --title "gluons"
# [i] settings summary:
# - number of jets 12573
# - sub item lg0 : -i eec_lund_gluons_100GeV_50000_noUE.parquet --title "split 0" --nsplit 0 --lund-eec --line-color w
# [i] settings summary:
# - number of jets 12573
# ...
