# %%
import joblib
import seaborn as sns
sns.set()

# %%
dt = joblib.load('aleph_timing.joblib')

# %%
dt.describe()
# Out:
#                 old           new       old/new       new-old        nparts
# count  14024.000000  14024.000000  14024.000000  14024.000000  14024.000000
# mean       0.000219      0.001036      0.210690      0.000817     29.437892
# std        0.000147      0.000188      0.112911      0.000205      7.195381
# min        0.000060      0.000813      0.053615     -0.013763      6.000000
# 25%        0.000173      0.000945      0.174129      0.000744     24.000000
# 50%        0.000204      0.000992      0.201754      0.000781     29.000000
# 75%        0.000242      0.001059      0.233611      0.000832     34.000000
# max        0.015046      0.004646     11.728117      0.004339     62.000000

# %%
sns.pairplot(data=dt)

# %%
len(dt)
# Out:
# 14024
